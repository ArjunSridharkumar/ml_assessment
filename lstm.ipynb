# %%
import pandas as pd

# %%
london_data = pd.read_csv("LondonBikeJourneyAug2023.csv")
london_data.columns
# Out:
# Index(['Number', 'Start date', 'Start station number', 'Start station',
#        'End date', 'End station number', 'End station', 'Bike number',
#        'Bike model', 'Total duration', 'Total duration (ms)'],
#       dtype='object')

# %%
london_data
# Out:
#            Number       Start date  Start station number  \
# 0       132825189    8/1/2023 0:00                  1190
# 1       132825190    8/1/2023 0:00                  1190
# 2       132825191    8/1/2023 0:00                   983
# 3       132825192    8/1/2023 0:01                  3479
# 4       132825193    8/1/2023 0:01                  1219
# ...           ...              ...                   ...
# 776522  133624570  8/31/2023 23:59                   988
# 776523  133624571  8/31/2023 23:59                  2660
# 776524  133624572  8/31/2023 23:59                200190
# 776525  133624573  8/31/2023 23:59                   959
# 776526  133624569  8/31/2023 23:59                200163
#
#                                 Start station       End date  \
# 0       Kennington Lane Rail Bridge, Vauxhall  8/1/2023 0:17
# 1       Kennington Lane Rail Bridge, Vauxhall  8/1/2023 0:17
# 2                         Euston Road, Euston  8/1/2023 0:11
# ...

# %%
cleaned_dataset = pd.read_csv("archive/Cleaned_dataset.csv")

# %%
cleaned_dataset.columns
# Out:
# Index(['Date_of_journey', 'Journey_day', 'Airline', 'Flight_code', 'Class',
#        'Source', 'Departure', 'Total_stops', 'Arrival', 'Destination',
#        'Duration_in_hours', 'Days_left', 'Fare'],
#       dtype='object')

# %%
cleaned_dataset.head()
# Out:
#   Date_of_journey Journey_day    Airline Flight_code    Class Source  \
# 0      2023-01-16      Monday   SpiceJet     SG-8169  Economy  Delhi
# 1      2023-01-16      Monday     Indigo     6E-2519  Economy  Delhi
# 2      2023-01-16      Monday   GO FIRST      G8-354  Economy  Delhi
# 3      2023-01-16      Monday   SpiceJet     SG-8709  Economy  Delhi
# 4      2023-01-16      Monday  Air India      AI-805  Economy  Delhi
#
#     Departure Total_stops      Arrival Destination  Duration_in_hours  \
# 0  After 6 PM    non-stop   After 6 PM      Mumbai             2.0833
# 1  After 6 PM    non-stop  Before 6 AM      Mumbai             2.3333
# 2  After 6 PM    non-stop  Before 6 AM      Mumbai             2.1667
# 3  After 6 PM    non-stop   After 6 PM      Mumbai             2.0833
# 4  After 6 PM    non-stop   After 6 PM      Mumbai             2.1667
#
#    Days_left  Fare
# 0          1  5335
# 1          1  5899
# 2          1  5801
# 3          1  5794
# 4          1  5955

# %%
scraped_dataset = pd.read_csv("archive/Scraped_dataset.csv")
scraped_dataset.columns()

# %%
scraped_dataset.head()

# %%
climate_train_dataset = pd.read_csv("DailyDelhiClimateTrain.csv")
climate_train_dataset
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
climate_train_dataset.columns
# Out:
# Index(['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure'], dtype='object')

# %%
#Check for na values or null values.
print (climate_train_dataset.isna().sum())
climate_train_dataset.isnull().values.any()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64
# np.False_

# %%
#check for distribution of data
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(climate_train_dataset.meantemp, bins=30, kde=True)
plt.show()
#Our data is not normally distributed. We can perform normalization to get the data uniformly distributed. 
# from sklearn.preprocessing import StandardScaler, MinMaxScaler
# scaler = StandardScaler()
# # climate_train_dataset.standardized_meantemp = scaler.fit_transform(climate_train_dataset.meantemp)
# meantemp_data_transformed = climate_train_dataset['meantemp'].values.reshape(-1, 1)
# meantemp_data_transformed_z_scaled = scaler.fit_transform(meantemp_data_transformed)
# climate_train_dataset['z_score_scaled_meantemp'] = meantemp_data_transformed_z_scaled
# fig, axes = plt.subplots(1, 2, figsize=(12, 6))
# sns.histplot(climate_train_dataset.meantemp, bins=30, kde=True, ax=axes[0])
# axes[0].set_title('Meantemp data')
# sns.histplot(climate_train_dataset.z_score_scaled_meantemp, bins=30, kde=True, ax=axes[1])
# axes[1].set_title('Normalized (Z score scaled) data')

# normalizer = MinMaxScaler(feature_range=(0, 1))
# meantemp_data_transformed = climate_train_dataset['meantemp'].values.reshape(-1, 1)
# meantemp_data_transformed_min_max_scaled = normalizer.fit_transform(meantemp_data_transformed)
# climate_train_dataset['min_max_scaled_meantemp'] = meantemp_data_transformed_min_max_scaled
# fig, axes = plt.subplots(1, 2, figsize=(12, 6))
# sns.histplot(climate_train_dataset.meantemp, bins=30, kde=True, ax=axes[0])
# axes[0].set_title('Meantemp data')
# sns.histplot(climate_train_dataset.min_max_scaled_meantemp, bins=30, kde=True, ax=axes[1])
# axes[1].set_title('Normalized (Min max score scaled) data')
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Z-score scaling
scaler = StandardScaler()
meantemp_data_transformed = climate_train_dataset['meantemp'].values.reshape(-1, 1)
meantemp_data_transformed_z_scaled = scaler.fit_transform(meantemp_data_transformed)
climate_train_dataset['z_score_scaled_meantemp'] = meantemp_data_transformed_z_scaled

# Plot original and Z-score scaled data
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(climate_train_dataset.meantemp, bins=30, kde=True, ax=axes[0])
axes[0].set_title('Meantemp data')
sns.histplot(climate_train_dataset.z_score_scaled_meantemp, bins=30, kde=True, ax=axes[1])
axes[1].set_title('Z-Score Scaled Meantemp Data')
plt.show()

# Min-Max scaling
normalizer = MinMaxScaler(feature_range=(0, 1))
meantemp_data_transformed_min_max_scaled = normalizer.fit_transform(meantemp_data_transformed)
climate_train_dataset['min_max_scaled_meantemp'] = meantemp_data_transformed_min_max_scaled

# Plot original and Min-Max scaled data
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(climate_train_dataset.meantemp, bins=30, kde=True, ax=axes[0])
axes[0].set_title('Meantemp data')
sns.histplot(climate_train_dataset.min_max_scaled_meantemp, bins=30, kde=True, ax=axes[1])
axes[1].set_title('Min-Max Scaled Meantemp Data')
plt.show()

# %%
#apply lstm univariate analysis

# %%
#apply lstm multivariate analysis

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(time_steps, 1)))  # LSTM layer with 50 units
model.add(LSTM(units=50))  # Second LSTM layer
model.add(Dense(1))  # Output layer to predict the next value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 model = Sequential()
# ----> 2 model.add(LSTM(units=50, return_sequences=True, input_shape=(time_steps, 1)))  # LSTM layer with 50 units
#       3 model.add(LSTM(units=50))  # Second LSTM layer
#       4 model.add(Dense(1))  # Output layer to predict the next value
#
# File /workspaces/ml_assessment/myenv/lib/python3.12/site-packages/keras/src/models/sequential.py:121, in Sequential.add(self, layer, rebuild)
#     119 self._layers.append(layer)
#     120 if rebuild:
# --> 121     self._maybe_rebuild()
#     122 else:
#     123     self.built = False
#
# File /workspaces/ml_assessment/myenv/lib/python3.12/site-packages/keras/src/models/sequential.py:140, in Sequential._maybe_rebuild(self)
#     138 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

meantemp_data = climate_train_dataset['z_score_scaled_meantemp'].values

def create_sequences(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 10  # You can adjust this number based on how many past observations you want to use
X, y = create_sequences(meantemp_data, time_steps)

# Step 3: Reshape the data to fit the LSTM input requirements (samples, timesteps, features)
print ("X.shape[1]", X.shape[1])
X = X.reshape((X.shape[0], X.shape[1], 1))
print (X.shape)
print (type(X))
print (type(y))
# X=np.squeeze(X)
# Step 4: Build the LSTM model
model = Sequential()
# input_shape=(time_steps, 1)
model.add(LSTM(units=50, return_sequences=True))  # LSTM layer with 50 units
model.add(LSTM(units=50))  # Second LSTM layer
model.add(Dense(1))  # Output layer to predict the next value

# Step 5: Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Step 6: Train the model
 # batch_size=32
model.fit(X, y, epochs=20)

# Step 7: Making predictions
# You can predict future values by providing the model with the most recent sequence of time steps
last_sequence = scaled_data[-time_steps:].reshape(1, time_steps, 1)
predicted_value = model.predict(last_sequence)

# Inverse transform to get the predicted value back in original scale
predicted_value_original = scaler.inverse_transform(predicted_value)
print("Predicted next value:", predicted_value_original)
# Out:
# X.shape[1] 10
# (1452, 10, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 38
#      34 model.compile(optimizer='adam', loss='mean_squared_error')
#      36 # Step 6: Train the model
#      37  # batch_size=32
# ---> 38 model.fit(X, y, epochs=20)
#      40 # Step 7: Making predictions
#      41 # You can predict future values by providing the model with the most recent sequence of time steps
#      42 last_sequence = scaled_data[-time_steps:].reshape(1, time_steps, 1)
#
# File /workspaces/ml_assessment/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
# ...

# %%
X.shape
# Out:
# (1452, 10, 1)

# %%
# !pip install -U numpy
import numpy
numpy.__version__
# Out:
# '2.1.1'

# %%
    # !pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/d7/24/f7b5c130975303efa4a91341e294fd784b94910c2a4c0f0f0561e5fc7405/tensorflow-2.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached tensorflow-2.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# ...
#   Obtaining dependency information for numpy<2.0.0,>=1.26.0 from https://files.pythonhosted.org/packages/0f/50/de23fde84e45f5c4fda2488c759b69990fd4512387a8632860f3ac9cd225/numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached tensorflow-2.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.4 MB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# ...
